# %%
import pandas as pd
BTC=pd.read_csv("data/Bitcoin_hist.csv")
ETH = pd.read_csv("data/Ethereum_hist.csv")
AVL= pd.read_csv("data/Avalanche_hist.csv")
BIN= pd.read_csv("data/BinanceUSD_hist.csv")
BNB= pd.read_csv("data/BNB_hist.csv")
CAR= pd.read_csv("data/Cardano_hist.csv")
COS= pd.read_csv("data/Cosmos_hist.csv")
CRO= pd.read_csv("data/Cronos_hist.csv")
DAI= pd.read_csv("data/Dai_hist.csv")
DOG= pd.read_csv("data/Dogecoin_hist.csv")
PLK= pd.read_csv("data/Polkadot_hist.csv")
POL= pd.read_csv("data/Polygon_hist.csv")
SHI= pd.read_csv("data/ShibaInu_hist.csv")
SOL= pd.read_csv("data/Solana_hist.csv")
TER= pd.read_csv("data/Terra_hist.csv")
TETH= pd.read_csv("data/Tether_hist.csv")
USD= pd.read_csv("data/USDcoin_hist.csv")
WRAP= pd.read_csv("data/WrappedBitcoin_hist.csv")
XRP= pd.read_csv("data/XRP_hist.csv")

# %%
shape = BTC.shape
shape
# Out:
# (365, 9)

# %%
shape= ETH.shape
shape
# Out:
# (365, 9)

# %%
shape= AVL.shape
shape
# Out:
# (365, 9)

# %%
shape= BIN.shape
shape
# Out:
# (365, 9)

# %%
shape= BNB.shape
shape
# Out:
# (365, 9)

# %%
shape= CAR.shape
shape
# Out:
# (365, 9)

# %%
shape= COS.shape
shape
# Out:
# (365, 9)

# %%
shape= CRO.shape
shape
# Out:
# (365, 9)

# %%
shape= DAI.shape
shape
# Out:
# (365, 9)

# %%
shape= DOG.shape
shape
# Out:
# (365, 9)

# %%
shape= PLK.shape
shape
# Out:
# (365, 9)

# %%
shape= POL.shape
shape
# Out:
# (365, 9)

# %%
shape= SHI.shape
shape
# Out:
# (365, 9)

# %%
shape= SOL.shape
shape
# Out:
# (365, 9)

# %%
shape= TER.shape
shape
# Out:
# (365, 9)

# %%
shape= TETH.shape
shape
# Out:
# (365, 9)

# %%
shape= USD.shape
shape
# Out:
# (365, 9)

# %%
shape= WRAP.shape
shape
# Out:
# (365, 9)

# %%
shape= XRP.shape
shape
# Out:
# (365, 9)

# %%
ftr = BTC.head()
ftr
# Out:
#   currency ticker        date  open_price      high       low  close_price  \
# 0  Bitcoin    BTC  2022-02-26    39213.08  40005.35  38702.53     39105.15
# 1  Bitcoin    BTC  2022-02-25    38333.75  39630.32  38111.34     39214.22
# 2  Bitcoin    BTC  2022-02-24    37278.57  38968.84  34459.22     38332.61
# 3  Bitcoin    BTC  2022-02-23    38285.28  39122.39  37201.82     37296.57
# 4  Bitcoin    BTC  2022-02-22    37068.77  38359.85  36488.93     38286.03
#
#          volume    market_cap
# 0  1.746755e+10  7.417897e+11
# 1  2.654560e+10  7.438278e+11
# 2  4.638380e+10  7.270726e+11
# 3  2.184907e+10  7.073908e+11
# 4  2.549315e+10  7.261215e+11

# %%
ftr = ETH.head()
ftr
# Out:
#    currency ticker        date  open_price     high      low  close_price  \
# 0  Ethereum    ETH  2022-02-26     2764.99  2849.42  2745.01      2781.11
# 1  Ethereum    ETH  2022-02-25     2598.44  2821.97  2579.21      2764.54
# 2  Ethereum    ETH  2022-02-24     2588.17  2689.05  2308.91      2598.07
# 3  Ethereum    ETH  2022-02-23     2639.45  2741.37  2587.41      2590.36
# 4  Ethereum    ETH  2022-02-22     2572.90  2648.92  2510.68      2639.30
#
#          volume    market_cap
# 0  1.172465e+10  3.330242e+11
# 1  1.720890e+10  3.310016e+11
# 2  2.931234e+10  3.110350e+11
# 3  1.338264e+10  3.100770e+11
# 4  1.636020e+10  3.158992e+11

# %%
ftr = AVL.head()
ftr
# Out:
#     currency ticker        date  open_price   high    low  close_price  \
# 0  Avalanche   AVAX  2022-02-26       80.85  84.87  78.50        81.88
# 1  Avalanche   AVAX  2022-02-25       76.54  81.86  72.95        80.83
# 2  Avalanche   AVAX  2022-02-24       73.67  79.32  64.83        76.52
# 3  Avalanche   AVAX  2022-02-23       74.54  81.84  73.70        73.70
# 4  Avalanche   AVAX  2022-02-22       70.00  74.76  67.46        74.57
#
#          volume    market_cap
# 0  1.419135e+09  2.013938e+10
# 1  1.884196e+09  1.987246e+10
# 2  3.097306e+09  1.880502e+10
# 3  1.699397e+09  1.810366e+10
# 4  1.344002e+09  1.831048e+10

# %%
ftr = BIN.head()
ftr
# Out:
#       currency ticker        date  open_price  high     low  close_price  \
# 0  Binance USD   BUSD  2022-02-26      1.0000   1.0  0.9982       1.0000
# 1  Binance USD   BUSD  2022-02-25      0.9997   1.0  0.9983       1.0000
# 2  Binance USD   BUSD  2022-02-24      0.9997   1.0  0.9979       0.9998
# 3  Binance USD   BUSD  2022-02-23      1.0000   1.0  0.9981       0.9997
# 4  Binance USD   BUSD  2022-02-22      0.9986   1.0  0.9977       1.0000
#
#          volume    market_cap
# 0  3.994663e+09  1.814591e+10
# 1  5.625014e+09  1.814235e+10
# 2  9.044548e+09  1.854989e+10
# 3  4.784158e+09  1.826053e+10
# 4  5.003667e+09  1.830390e+10

# %%
ftr = BNB.head()
ftr
# Out:
#   currency ticker        date  open_price    high     low  close_price  \
# 0      BNB    BNB  2022-02-26      374.89  385.21  371.48       373.64
# 1      BNB    BNB  2022-02-25      361.22  376.80  357.37       374.91
# 2      BNB    BNB  2022-02-24      366.35  368.17  324.48       361.23
# 3      BNB    BNB  2022-02-23      374.30  383.25  366.54       366.54
# 4      BNB    BNB  2022-02-22      356.73  374.86  350.15       374.31
#
#          volume    market_cap
# 0  1.319209e+09  6.169402e+10
# 1  1.839035e+09  6.190474e+10
# 2  2.972952e+09  5.964589e+10
# 3  1.644708e+09  6.052181e+10
# 4  2.037210e+09  6.180443e+10

# %%
ftr = CAR.head()
ftr
# Out:
#   currency ticker        date  open_price    high     low  close_price  \
# 0  Cardano    ADA  2022-02-26      0.8980  0.9283  0.8854       0.8879
# 1  Cardano    ADA  2022-02-25      0.8536  0.9065  0.8292       0.8980
# 2  Cardano    ADA  2022-02-24      0.8685  0.8823  0.7528       0.8534
# 3  Cardano    ADA  2022-02-23      0.8890  0.9554  0.8692       0.8692
# 4  Cardano    ADA  2022-02-22      0.8581  0.8938  0.8200       0.8890
#
#          volume    market_cap
# 0  1.099935e+09  2.987679e+10
# 1  1.652894e+09  3.021016e+10
# 2  3.629368e+09  2.870977e+10
# 3  1.824386e+09  2.922707e+10
# 4  2.058500e+09  2.989448e+10

# %%
ftr = COS.head()
ftr
# Out:
#   currency ticker        date  open_price   high    low  close_price  \
# 0   Cosmos   ATOM  2022-02-26       27.23  30.29  27.21        29.81
# 1   Cosmos   ATOM  2022-02-25       24.94  27.40  24.35        27.23
# 2   Cosmos   ATOM  2022-02-24       25.28  25.48  21.75        24.95
# 3   Cosmos   ATOM  2022-02-23       24.86  26.86  24.63        25.29
# 4   Cosmos   ATOM  2022-02-22       23.84  24.95  23.22        24.86
#
#          volume    market_cap
# 0  1.069524e+09  8.535952e+09
# 1  8.985584e+08  7.796697e+09
# 2  1.378415e+09  7.143533e+09
# 3  7.879145e+08  7.241577e+09
# 4  7.045669e+08  7.119663e+09

# %%
ftr = CRO.head()
ftr
# Out:
#   currency ticker        date  open_price    high     low  close_price  \
# 0   Cronos    CRO  2022-02-26      0.4179  0.4263  0.4118       0.4138
# 1   Cronos    CRO  2022-02-25      0.3945  0.4209  0.3945       0.4179
# 2   Cronos    CRO  2022-02-24      0.3990  0.4042  0.3477       0.3945
# 3   Cronos    CRO  2022-02-23      0.4040  0.4199  0.3963       0.3994
# 4   Cronos    CRO  2022-02-22      0.3859  0.4050  0.3711       0.4040
#
#         volume    market_cap
# 0   90351075.0  1.045297e+10
# 1  132609761.0  1.055622e+10
# 2  220041913.0  9.965363e+09
# 3  125535148.0  1.008888e+10
# 4  135762941.0  1.020591e+10

# %%
ftr = DAI.head()
ftr
# Out:
#   currency ticker        date  open_price  high     low  close_price  \
# 0      Dai    DAI  2022-02-26      0.9997   1.0  0.9990       1.0000
# 1      Dai    DAI  2022-02-25      1.0000   1.0  0.9990       0.9997
# 2      Dai    DAI  2022-02-24      0.9995   1.0  0.9980       1.0000
# 3      Dai    DAI  2022-02-23      1.0000   1.0  0.9985       0.9995
# 4      Dai    DAI  2022-02-22      0.9994   1.0  0.9983       1.0000
#
#         volume    market_cap
# 0  205336506.0  9.659729e+09
# 1  330433421.0  9.670568e+09
# 2  646259155.0  9.885096e+09
# 3  334297814.0  1.007249e+10
# 4  358833503.0  1.009965e+10

# %%
ftr = DOG.head()
ftr
# Out:
#    currency ticker        date  open_price    high     low  close_price  \
# 0  Dogecoin   DOGE  2022-02-26      0.1276  0.1301  0.1262       0.1276
# 1  Dogecoin   DOGE  2022-02-25      0.1238  0.1282  0.1210       0.1276
# 2  Dogecoin   DOGE  2022-02-24      0.1278  0.1279  0.1096       0.1238
# 3  Dogecoin   DOGE  2022-02-23      0.1316  0.1353  0.1278       0.1278
# 4  Dogecoin   DOGE  2022-02-22      0.1285  0.1317  0.1254       0.1316
#
#          volume    market_cap
# 0  5.355757e+08  1.693499e+10
# 1  8.051611e+08  1.692555e+10
# 2  2.046477e+09  1.642633e+10
# 3  5.874729e+08  1.696145e+10
# 4  7.119671e+08  1.745320e+10

# %%
ftr = PLK.head()
ftr
# Out:
#    currency ticker        date  open_price   high    low  close_price  \
# 0  Polkadot    DOT  2022-02-26       17.25  18.67  17.22        18.02
# 1  Polkadot    DOT  2022-02-25       16.17  17.41  15.84        17.25
# 2  Polkadot    DOT  2022-02-24       16.00  16.55  14.14        16.17
# 3  Polkadot    DOT  2022-02-23       16.57  17.40  15.97        16.01
# 4  Polkadot    DOT  2022-02-22       16.19  16.67  15.84        16.56
#
#          volume    market_cap
# 0  1.418828e+09  1.780068e+10
# 1  1.228501e+09  1.703605e+10
# 2  2.249049e+09  1.597006e+10
# 3  1.280517e+09  1.581072e+10
# 4  1.116940e+09  1.635854e+10

# %%
ftr = POL.head()
ftr
# Out:
#   currency ticker        date  open_price  high   low  close_price  \
# 0  Polygon  MATIC  2022-02-26        1.55  1.59  1.51         1.52
# 1  Polygon  MATIC  2022-02-25        1.44  1.57  1.41         1.55
# 2  Polygon  MATIC  2022-02-24        1.44  1.49  1.25         1.44
# 3  Polygon  MATIC  2022-02-23        1.46  1.59  1.44         1.44
# 4  Polygon  MATIC  2022-02-22        1.41  1.47  1.36         1.46
#
#          volume    market_cap
# 0  8.985680e+08  1.142206e+10
# 1  1.599951e+09  1.168857e+10
# 2  2.679134e+09  1.085143e+10
# 3  1.457761e+09  1.086436e+10
# 4  1.347670e+09  1.103084e+10

# %%
ftr = SHI.head()
ftr
# Out:
#     currency ticker        date  open_price      high       low  close_price  \
# 0  Shiba Inu   SHIB  2022-02-26    0.000025  0.000026  0.000024     0.000024
# 1  Shiba Inu   SHIB  2022-02-25    0.000024  0.000025  0.000023     0.000025
# 2  Shiba Inu   SHIB  2022-02-24    0.000025  0.000025  0.000021     0.000024
# 3  Shiba Inu   SHIB  2022-02-23    0.000025  0.000027  0.000025     0.000025
# 4  Shiba Inu   SHIB  2022-02-22    0.000024  0.000025  0.000023     0.000025
#
#          volume    market_cap
# 0  1.099352e+09  1.340792e+10
# 1  1.740382e+09  1.363392e+10
# 2  3.275039e+09  1.310501e+10
# 3  1.728130e+09  1.372200e+10
# 4  1.524044e+09  1.370566e+10

# %%
ftr = SOL.head()
ftr
# Out:
#   currency ticker        date  open_price   high    low  close_price  \
# 0   Solana    SOL  2022-02-26       92.61  94.60  89.76        90.14
# 1   Solana    SOL  2022-02-25       89.23  94.78  87.28        92.60
# 2   Solana    SOL  2022-02-24       84.86  92.28  76.86        89.19
# 3   Solana    SOL  2022-02-23       86.47  92.74  84.90        84.90
# 4   Solana    SOL  2022-02-22       83.11  87.16  81.20        86.47
#
#          volume    market_cap
# 0  1.721042e+09  2.883888e+10
# 1  3.069243e+09  2.962508e+10
# 2  5.253579e+09  2.853607e+10
# 3  2.293962e+09  2.715107e+10
# 4  2.046554e+09  2.765098e+10

# %%
ftr = TER.head()
ftr
# Out:
#   currency ticker        date  open_price   high    low  close_price  \
# 0    Terra   LUNA  2022-02-26       73.16  79.51  72.42        78.08
# 1    Terra   LUNA  2022-02-25       65.37  73.29  64.06        73.17
# 2    Terra   LUNA  2022-02-24       59.63  65.46  50.52        65.39
# 3    Terra   LUNA  2022-02-23       54.77  63.99  54.71        59.65
# 4    Terra   LUNA  2022-02-22       50.16  55.25  48.59        54.78
#
#          volume    market_cap
# 0  3.159163e+09  2.962125e+10
# 1  4.158265e+09  2.786811e+10
# 2  6.147403e+09  2.501772e+10
# 3  3.103073e+09  2.297743e+10
# 4  2.312185e+09  2.119547e+10

# %%
ftr = TETH.head()
ftr
# Out:
#   currency ticker        date  open_price  high  low  close_price  \
# 0   Tether   USDT  2022-02-26         1.0   1.0  1.0          1.0
# 1   Tether   USDT  2022-02-25         1.0   1.0  1.0          1.0
# 2   Tether   USDT  2022-02-24         1.0   1.0  1.0          1.0
# 3   Tether   USDT  2022-02-23         1.0   1.0  1.0          1.0
# 4   Tether   USDT  2022-02-22         1.0   1.0  1.0          1.0
#
#          volume    market_cap
# 0  4.670869e+10  7.957165e+10
# 1  6.602535e+10  7.952116e+10
# 2  1.079520e+11  7.952518e+10
# 3  5.484561e+10  7.945477e+10
# 4  6.053926e+10  7.941054e+10

# %%
ftr = USD.head()
ftr
# Out:
#    currency ticker        date  open_price  high     low  close_price  \
# 0  USD Coin   USDC  2022-02-26      0.9999   1.0  0.9991       1.0000
# 1  USD Coin   USDC  2022-02-25      0.9999   1.0  0.9993       0.9999
# 2  USD Coin   USDC  2022-02-24      0.9995   1.0  0.9988       1.0000
# 3  USD Coin   USDC  2022-02-23      1.0000   1.0  0.9989       0.9995
# 4  USD Coin   USDC  2022-02-22      0.9994   1.0  0.9988       1.0000
#
#          volume    market_cap
# 0  3.262045e+09  5.329042e+10
# 1  5.563465e+09  5.326856e+10
# 2  9.044961e+09  5.312670e+10
# 3  4.088593e+09  5.279760e+10
# 4  4.311029e+09  5.272413e+10

# %%
ftr = WRAP.head()
ftr
# Out:
#           currency ticker        date  open_price      high       low  \
# 0  Wrapped Bitcoin   WBTC  2022-02-26    39236.82  39863.65  38818.91
# 1  Wrapped Bitcoin   WBTC  2022-02-25    38277.17  39508.94  38203.45
# 2  Wrapped Bitcoin   WBTC  2022-02-24    37256.68  38759.47  34573.51
# 3  Wrapped Bitcoin   WBTC  2022-02-23    38231.15  39082.69  37230.61
# 4  Wrapped Bitcoin   WBTC  2022-02-22    37089.52  38264.43  36545.87
#
#    close_price       volume    market_cap
# 0     39068.00  149601888.0  1.026559e+10
# 1     39243.11  325327024.0  1.031161e+10
# 2     38276.02  461473124.0  1.007280e+10
# 3     37260.75  150897606.0  9.805622e+09
# 4     38230.69  188206786.0  1.006087e+10

# %%
ftr = XRP.head()
ftr
# Out:
#   currency ticker        date  open_price    high     low  close_price  \
# 0      XRP    XRP  2022-02-26      0.7686  0.7882  0.7436       0.7510
# 1      XRP    XRP  2022-02-25      0.6963  0.7689  0.6858       0.7689
# 2      XRP    XRP  2022-02-24      0.6986  0.7129  0.6271       0.6963
# 3      XRP    XRP  2022-02-23      0.7229  0.7389  0.6963       0.6987
# 4      XRP    XRP  2022-02-22      0.7033  0.7252  0.6788       0.7228
#
#          volume    market_cap
# 0  3.051696e+09  3.600864e+10
# 1  3.460713e+09  3.686834e+10
# 2  5.146799e+09  3.338575e+10
# 3  2.690185e+09  3.350438e+10
# 4  3.539593e+09  3.465933e+10

# %%
most = BTC.describe()
most
# Out:
#          open_price          high           low   close_price        volume  \
# count    365.000000    365.000000    365.000000    365.000000  3.650000e+02
# mean   47610.209699  48827.954000  46174.285342  47579.798137  3.952534e+10
# std     9287.860471   9391.177151   9210.753116   9289.042701  1.597781e+10
# min    29796.290000  31006.190000  28893.620000  29807.350000  1.373656e+10
# 25%    39995.450000  40929.150000  38176.030000  39974.900000  2.847970e+10
# 50%    47169.370000  48431.400000  46288.490000  47166.690000  3.608489e+10
# 75%    56099.910000  57688.660000  54253.580000  56048.940000  4.768658e+10
# max    67549.740000  68789.630000  66382.060000  67566.830000  1.263581e+11
#
#          market_cap
# count  3.650000e+02
# mean   8.945334e+11
# std    1.741610e+11
# min    5.592443e+11
# 25%    7.504724e+11
# 50%    8.868699e+11
# 75%    1.050445e+12
# max    1.274831e+12

# %%
most = ETH.describe()
most
# Out:
#         open_price         high          low  close_price        volume  \
# count   365.000000   365.000000   365.000000   365.000000  3.650000e+02
# mean   3015.165507  3116.988110  2898.153452  3017.987178  2.380376e+10
# std     855.136783   869.934905   835.031122   849.575932  1.099881e+10
# min    1417.150000  1468.390000  1300.470000  1416.050000  9.054964e+09
# 25%    2317.950000  2396.450000  2168.880000  2316.060000  1.659947e+10
# 50%    3002.960000  3154.620000  2888.710000  3001.680000  2.138325e+10
# 75%    3747.160000  3836.870000  3595.200000  3745.440000  2.741750e+10
# max    4810.070000  4891.700000  4718.040000  4812.090000  8.448291e+10
#
#          market_cap
# count  3.650000e+02
# mean   3.547286e+11
# std    1.021132e+11
# min    1.626504e+11
# 25%    2.692600e+11
# 50%    3.534213e+11
# 75%    4.417925e+11
# max    5.690943e+11

# %%
most = AVL.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean    51.640137   54.816685   48.748712    51.804192  7.537408e+08
# std     33.253518   34.922282   31.645044    33.293674  6.823340e+08
# min      9.640000   10.340000    9.340000     9.650000  3.146806e+07
# 25%     23.430000   25.500000   20.460000    23.500000  1.772928e+08
# 50%     42.480000   48.230000   40.480000    43.530000  5.831183e+08
# 75%     78.200000   81.860000   74.620000    78.690000  1.138103e+09
# max    134.870000  146.220000  126.190000   134.530000  3.379296e+09
#
#          market_cap
# count  3.650000e+02
# mean   1.094652e+10
# std    8.705995e+09
# min    1.663937e+09
# 25%    2.814909e+09
# 50%    8.067278e+09
# 75%    1.893662e+10
# max    3.011462e+10

# %%
most = BIN.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     0.999893    1.000219    0.999119     0.999891  6.442832e+09
# std      0.000604    0.002085    0.000765     0.000610  1.636943e+10
# min      0.998200    1.000000    0.995300     0.998100  2.371263e+09
# 25%      0.999900    1.000000    0.998300     0.999900  3.994663e+09
# 50%      1.000000    1.000000    0.999400     1.000000  5.103610e+09
# 75%      1.000000    1.000000    0.999800     1.000000  6.747147e+09
# max      1.010000    1.030000    1.000000     1.010000  3.155511e+11
#
#          market_cap
# count  3.650000e+02
# mean   1.109446e+10
# std    3.927882e+09
# min    2.330838e+09
# 25%    8.828317e+09
# 50%    1.228468e+10
# 75%    1.361566e+10
# max    1.854989e+10

# %%
most = BNB.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean   429.328521  445.318438  411.455945   429.597753  2.832793e+09
# std    113.889237  116.261925  110.641713   113.121995  1.683517e+09
# min    209.950000  228.170000  195.850000   209.570000  1.113777e+09
# 25%    337.550000  352.700000  320.240000   339.010000  1.720990e+09
# 50%    415.190000  430.730000  400.810000   415.120000  2.247005e+09
# 75%    520.630000  534.780000  503.040000   520.420000  3.548217e+09
# max    676.320000  690.930000  634.550000   675.680000  1.443632e+10
#
#          market_cap
# count  3.650000e+02
# mean   6.978865e+10
# std    1.910204e+10
# min    3.238612e+10
# 25%    5.412169e+10
# 50%    6.951730e+10
# 75%    8.484529e+10
# max    1.091405e+11

# %%
most = CAR.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     1.592012    1.658959    1.519161     1.591297  3.628112e+09
# std      0.488528    0.508092    0.469961     0.489604  2.754153e+09
# min      0.853600    0.882300    0.752800     0.853400  7.480846e+08
# 25%      1.220000    1.280000    1.180000     1.220000  1.759461e+09
# 50%      1.400000    1.460000    1.330000     1.400000  2.675040e+09
# 75%      1.990000    2.040000    1.920000     1.990000  4.675923e+09
# max      2.970000    3.100000    2.910000     2.970000  1.914198e+10
#
#          market_cap
# count  3.650000e+02
# mean   5.170006e+10
# std    1.568777e+10
# min    2.870977e+10
# 25%    3.958415e+10
# 50%    4.549574e+10
# 75%    6.533014e+10
# max    9.502550e+10

# %%
most = COS.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean    24.286630   25.676274   22.828082    24.311589  8.000965e+08
# std      9.002681    9.455459    8.479291     9.006432  6.678097e+08
# min      8.970000    9.540000    7.890000     8.970000  1.449177e+08
# 25%     17.210000   18.570000   15.510000    17.210000  3.503099e+08
# 50%     23.540000   24.950000   22.080000    23.590000  5.973074e+08
# 75%     31.920000   33.160000   29.720000    31.890000  9.413850e+08
# max     44.280000   44.700000   39.220000    44.540000  4.260700e+09
#
#          market_cap
# count  3.650000e+02
# mean   5.551174e+09
# std    2.269735e+09
# min    1.891278e+09
# 25%    3.648695e+09
# 50%    5.102457e+09
# 75%    7.642895e+09
# max    1.118510e+10

# %%
most = CRO.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     0.270022    0.283195    0.257568     0.270652  1.909165e+08
# std      0.176917    0.187793    0.166501     0.176747  2.857544e+08
# min      0.088520    0.095150    0.081040     0.088530  2.579974e+07
# 25%      0.147200    0.152700    0.140400     0.147200  4.900738e+07
# 50%      0.188600    0.194200    0.183100     0.188500  1.128256e+08
# 75%      0.404000    0.428000    0.392400     0.404600  2.057825e+08
# max      0.899200    0.969800    0.839900     0.900500  2.115234e+09
#
#          market_cap
# count  3.650000e+02
# mean   6.829383e+09
# std    4.470152e+09
# min    2.236551e+09
# 25%    3.651008e+09
# 50%    4.754781e+09
# 75%    1.022045e+10
# max    2.274979e+10

# %%
most = DAI.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     1.000018    1.010409    0.998537     1.000015  4.978316e+08
# std      0.001809    0.142069    0.002359     0.001817  2.584981e+08
# min      0.988100    0.999300    0.979800     0.987800  1.811150e+08
# 25%      1.000000    1.000000    0.998400     1.000000  3.304334e+08
# 50%      1.000000    1.000000    0.999200     1.000000  4.212119e+08
# 75%      1.000000    1.000000    0.999800     1.000000  5.847341e+08
# max      1.010000    3.670000    1.000000     1.010000  2.451528e+09
#
#          market_cap
# count  3.650000e+02
# mean   6.131233e+09
# std    2.141404e+09
# min    2.315557e+09
# 25%    4.766608e+09
# 50%    6.109478e+09
# 75%    6.508647e+09
# max    1.037631e+10

# %%
most = DOG.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     0.222764    0.236939    0.208753     0.223046  3.741223e+09
# std      0.107228    0.120692    0.094005     0.107136  6.819307e+09
# min      0.048070    0.050130    0.045090     0.048050  3.639767e+08
# 25%      0.160200    0.169100    0.152100     0.160200  1.014713e+09
# 50%      0.218800    0.228300    0.204900     0.219100  1.628781e+09
# 75%      0.271900    0.289400    0.256400     0.272100  3.226346e+09
# max      0.687800    0.737600    0.608200     0.684800  6.941068e+10
#
#          market_cap
# count  3.650000e+02
# mean   2.919835e+10
# std    1.387248e+10
# min    6.177711e+09
# 25%    2.125560e+10
# 50%    2.866360e+10
# 75%    3.566834e+10
# max    8.868082e+10

# %%
most = PLK.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean    29.344904   30.726959   27.737973    29.302630  2.047894e+09
# std      9.797131   10.175816    9.396923     9.815053  1.236871e+09
# min     10.960000   11.550000   10.420000    10.980000  5.430308e+08
# 25%     21.370000   22.400000   19.990000    21.370000  1.236018e+09
# 50%     28.580000   30.260000   26.940000    28.310000  1.694814e+09
# 75%     36.520000   38.150000   34.600000    36.540000  2.535826e+09
# max     53.880000   55.000000   52.250000    53.880000  1.007000e+10
#
#          market_cap
# count  3.650000e+02
# mean   2.831712e+10
# std    9.421365e+09
# min    1.072993e+10
# 25%    2.045258e+10
# 50%    2.776151e+10
# 75%    3.446540e+10
# max    5.321248e+10

# %%
most = POL.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     1.352565    1.434647    1.271650     1.355214  1.419646e+09
# std      0.612284    0.641876    0.577636     0.608511  1.311718e+09
# min      0.190500    0.220900    0.174400     0.197500  1.274614e+08
# 25%      1.030000    1.060000    0.960500     1.030000  6.526226e+08
# 50%      1.420000    1.500000    1.320000     1.430000  9.925027e+08
# 75%      1.730000    1.870000    1.650000     1.730000  1.700044e+09
# max      2.880000    2.920000    2.710000     2.880000  9.181248e+09
#
#          market_cap
# count  3.650000e+02
# mean   9.081314e+09
# std    4.593645e+09
# min    9.810255e+08
# 25%    6.509735e+09
# 50%    9.246400e+09
# 75%    1.211373e+10
# max    2.041191e+10

# %%
most = SHI.describe()
most
# Out:
#          open_price          high           low   close_price        volume  \
# count  3.650000e+02  3.650000e+02  3.650000e+02  3.650000e+02  3.650000e+02
# mean   1.761904e-05  1.899333e-05  1.637668e-05  1.767718e-05  1.793245e+09
# std    1.687137e-05  1.821824e-05  1.550048e-05  1.684938e-05  3.728780e+09
# min    1.000000e-08  1.000000e-08  1.000000e-08  1.000000e-08  2.269580e+05
# 25%    6.440000e-06  6.900000e-06  6.160000e-06  6.470000e-06  2.683131e+08
# 50%    8.430000e-06  8.940000e-06  8.000000e-06  8.370000e-06  6.136210e+08
# 75%    2.959000e-05  3.156000e-05  2.790000e-05  2.958000e-05  1.740382e+09
# max    7.924000e-05  8.845000e-05  6.673000e-05  8.000000e-05  3.905385e+10
#
#          market_cap
# count  3.650000e+02
# mean   8.801876e+09
# std    9.310868e+09
# min    0.000000e+00
# 25%    2.554511e+09
# 50%    3.304294e+09
# 75%    1.559622e+10
# max    4.108324e+10

# %%
most = SOL.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean    97.168685  102.059562   92.164493    97.306137  1.890156e+09
# std     71.674175   74.257726   68.417072    71.452934  1.921109e+09
# min     12.570000   13.080000   11.490000    12.610000  6.422934e+07
# 25%     32.770000   34.980000   31.040000    32.930000  4.746293e+08
# 50%     83.110000   88.850000   76.860000    84.900000  1.540638e+09
# 75%    160.000000  168.850000  150.970000   159.120000  2.674183e+09
# max    258.780000  260.060000  246.120000   258.930000  1.706864e+10
#
#          market_cap
# count  3.650000e+02
# mean   2.912567e+10
# std    2.208807e+10
# min    3.302677e+09
# 25%    8.977346e+09
# 50%    2.658221e+10
# 75%    4.790030e+10
# max    7.799381e+10

# %%
most = TER.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean    33.169945   35.159863   31.343425    33.353562  1.129795e+09
# std     24.454657   25.670807   23.207154    24.515321  1.025578e+09
# min      4.090000    5.290000    3.940000     4.110000  6.139530e+07
# 25%     13.380000   14.350000   11.870000    13.410000  3.696444e+08
# 50%     30.000000   32.450000   27.240000    29.990000  7.782701e+08
# 75%     50.270000   52.470000   47.690000    50.390000  1.599656e+09
# max     99.560000  103.330000   95.970000    99.720000  6.147403e+09
#
#          market_cap
# count  3.650000e+02
# mean   1.303042e+10
# std    9.169876e+09
# min    1.599297e+09
# 25%    5.117122e+09
# 50%    1.212190e+10
# 75%    2.016693e+10
# max    3.626254e+10

# %%
most = TETH.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     0.999991    1.000301    0.999560     0.999998  8.354297e+10
# std      0.000544    0.002603    0.000642     0.000538  3.756370e+10
# min      0.998900    1.000000    0.997400     0.999000  3.370088e+10
# 25%      1.000000    1.000000    0.999500     1.000000  5.942648e+10
# 50%      1.000000    1.000000    0.999800     1.000000  7.608169e+10
# 75%      1.000000    1.000000    1.000000     1.000000  9.357607e+10
# max      1.010000    1.030000    1.000000     1.010000  2.790675e+11
#
#          market_cap
# count  3.650000e+02
# mean   6.414432e+10
# std    1.216816e+10
# min    3.502403e+10
# 25%    6.131054e+10
# 50%    6.553200e+10
# 75%    7.386830e+10
# max    7.957165e+10

# %%
most = USD.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     0.999907    1.004329    0.999275     0.999908  3.130499e+09
# std      0.000583    0.071209    0.000886     0.000581  1.403334e+09
# min      0.998100    1.000000    0.987400     0.998200  1.140401e+09
# 25%      0.999800    1.000000    0.999000     0.999900  2.034748e+09
# 50%      1.000000    1.000000    0.999500     1.000000  2.869319e+09
# 75%      1.000000    1.000000    0.999800     1.000000  3.839133e+09
# max      1.010000    2.350000    1.000000     1.010000  9.498203e+09
#
#          market_cap
# count  3.650000e+02
# mean   2.890079e+10
# std    1.256994e+10
# min    8.655540e+09
# 25%    2.223073e+10
# 50%    2.767111e+10
# 75%    3.822020e+10
# max    5.329042e+10

# %%
most = WRAP.describe()
most
# Out:
#          open_price           high           low   close_price        volume  \
# count    365.000000     365.000000    365.000000    365.000000  3.650000e+02
# mean   47566.955562   49024.478740  46194.903205  47538.585616  2.591686e+08
# std     9254.022286   11130.662868   9136.576394   9258.033303  1.198540e+08
# min    29706.660000   30947.710000  29099.160000  29707.060000  6.749569e+07
# 25%    39981.850000   40732.510000  38243.380000  39901.560000  1.769119e+08
# 50%    47242.190000   48354.430000  46424.000000  47186.210000  2.371989e+08
# 75%    55960.700000   57467.910000  54234.700000  55962.300000  3.130463e+08
# max    67540.310000  162188.260000  66458.720000  67549.230000  9.217607e+08
#
#          market_cap
# count  3.650000e+02
# mean   9.734570e+09
# std    2.560754e+09
# min    5.589787e+09
# 25%    7.667006e+09
# 50%    9.409649e+09
# 75%    1.153103e+10
# max    1.588311e+10

# %%
most = XRP.describe()
most
# Out:
#        open_price        high         low  close_price        volume  \
# count  365.000000  365.000000  365.000000   365.000000  3.650000e+02
# mean     0.922505    0.966273    0.875013     0.923509  5.075015e+09
# std      0.289424    0.311568    0.265568     0.288652  4.802812e+09
# min      0.415100    0.439400    0.397700     0.415000  8.708786e+08
# 25%      0.698600    0.728200    0.652300     0.701700  2.509436e+09
# 50%      0.894600    0.936900    0.847400     0.893700  3.477803e+09
# 75%      1.100000    1.150000    1.060000     1.100000  5.456909e+09
# max      1.840000    1.960000    1.660000     1.840000  3.695518e+10
#
#          market_cap
# count  3.650000e+02
# mean   4.242506e+10
# std    1.252521e+10
# min    1.884055e+10
# 25%    3.300821e+10
# 50%    4.164422e+10
# 75%    5.123171e+10
# max    8.350871e+10

# %%
nullcheck = BTC.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = ETH.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = AVL.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = BIN.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = BNB.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = CAR.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = COS.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = CRO.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = DAI.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = DOG.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = PLK.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = POL.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = SHI.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = SOL.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = TER.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = TETH.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = USD.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = WRAP.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
nullcheck = XRP.notna()
nullcheck
# Out:
#      currency  ticker  date  open_price  high   low  close_price  volume  \
# 0        True    True  True        True  True  True         True    True
# 1        True    True  True        True  True  True         True    True
# 2        True    True  True        True  True  True         True    True
# 3        True    True  True        True  True  True         True    True
# 4        True    True  True        True  True  True         True    True
# ..        ...     ...   ...         ...   ...   ...          ...     ...
# 360      True    True  True        True  True  True         True    True
# 361      True    True  True        True  True  True         True    True
# 362      True    True  True        True  True  True         True    True
# 363      True    True  True        True  True  True         True    True
# 364      True    True  True        True  True  True         True    True
#
#      market_cap
# 0          True
# 1          True
# 2          True
# 3          True
# ...

# %%
import os
import pandas as pd

def clean_crypto_csvs(folder_path="data"):
    for filename in os.listdir(folder_path):
        if filename.endswith("_hist.csv"):
            filepath = os.path.join(folder_path, filename)
            try:
                df = pd.read_csv(filepath)

                for col in ["open_price", "high", "low", "close_price", "volume", "market_cap"]:
                    if col in df.columns:
                        df[col] = df[col].replace({r'\$': '', ',': ''}, regex=True).astype(float)

                if "date" in df.columns:
                    df["date"] = pd.to_datetime(df["date"])

                df.to_csv(filepath, index=False)
                print(f"[✓] Cleaned: {filename}")

            except Exception as e:
                print(f"[!] Failed to clean {filename}: {e}")

# %%
clean_crypto_csvs("data")
# Out:
# [✓] Cleaned: Avalanche_hist.csv
# [✓] Cleaned: BinanceUSD_hist.csv
# [✓] Cleaned: Bitcoin_hist.csv
# [✓] Cleaned: BNB_hist.csv
# [✓] Cleaned: Cardano_hist.csv
# [✓] Cleaned: Cosmos_hist.csv
# [✓] Cleaned: Cronos_hist.csv
# [✓] Cleaned: Dai_hist.csv
# [✓] Cleaned: Dogecoin_hist.csv
# [✓] Cleaned: Ethereum_hist.csv
# [✓] Cleaned: Polkadot_hist.csv
# [✓] Cleaned: Polygon_hist.csv
# [✓] Cleaned: ShibaInu_hist.csv
# [✓] Cleaned: Solana_hist.csv
# [✓] Cleaned: Terra_hist.csv
# [✓] Cleaned: Tether_hist.csv
# [✓] Cleaned: USDCoin_hist.csv
# [✓] Cleaned: WrappedBitcoin_hist.csv
# [✓] Cleaned: XRP_hist.csv

# %%
ftr = BTC.head(10)
ftr
# Out:
#   currency ticker        date  open_price      high       low  close_price  \
# 0  Bitcoin    BTC  2022-02-26    39213.08  40005.35  38702.53     39105.15
# 1  Bitcoin    BTC  2022-02-25    38333.75  39630.32  38111.34     39214.22
# 2  Bitcoin    BTC  2022-02-24    37278.57  38968.84  34459.22     38332.61
# 3  Bitcoin    BTC  2022-02-23    38285.28  39122.39  37201.82     37296.57
# 4  Bitcoin    BTC  2022-02-22    37068.77  38359.85  36488.93     38286.03
# 5  Bitcoin    BTC  2022-02-21    38423.21  39394.44  36950.48     37075.28
# 6  Bitcoin    BTC  2022-02-20    40118.10  40119.89  38112.81     38431.38
# 7  Bitcoin    BTC  2022-02-19    40026.02  40418.88  39713.06     40122.15
# 8  Bitcoin    BTC  2022-02-18    40552.13  40929.15  39637.62     40030.98
# 9  Bitcoin    BTC  2022-02-17    43937.07  44132.97  40249.37     40538.01
#
#          volume    market_cap
# 0  1.746755e+10  7.417897e+11
# 1  2.654560e+10  7.438278e+11
# 2  4.638380e+10  7.270726e+11
# ...

# %%
# plot volume and price for bitcoin

fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot Closing Price on primary y-axis
ax1.set_xlabel('Date')
ax1.set_ylabel('Closing Price', color='blue')
ax1.plot(BTC['close_price'], BTC['volume'], color='blue', marker='o', label='Closing Price')
ax1.tick_params(axis='y', labelcolor='blue')

# Create secondary y-axis for Volume
ax2 = ax1.twinx()
ax2.set_ylabel('Volume', color='green')
ax2.plot(BTC['date'], BTC['volume'], color='green', marker='x', label='Volume')
ax2.tick_params(axis='y', labelcolor='green')

# Title and layout
plt.title('Closing Price and Volume Over Time')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt


BTC['date'] = pd.to_datetime(BTC['date'])

plt.figure(figsize=(10, 5))
plt.plot(BTC['date'], BTC['close_price'], marker='o')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.show()

# %%
import matplotlib.pyplot as plt

BTC['date'] = pd.to_datetime(BTC['date'])

fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot BTC closing price
ax1.plot(BTC['date'], BTC['close_price'], color='blue', marker='o', label='BTC Closing Price')
ax1.set_xlabel('Date')
ax1.set_ylabel('Closing Price', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Plot BTC volume on secondary y-axis
ax2 = ax1.twinx()
ax2.plot(BTC['date'], BTC['volume'], color='green', marker='x', label='BTC Volume')
ax2.set_ylabel('Volume', color='green')
ax2.tick_params(axis='y', labelcolor='green')

plt.title('BTC Closing Price and Volume Over Time')
fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

ETH['date'] = pd.to_datetime(ETH['date'])

fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot ETH closing price
ax1.plot(ETH['date'], ETH['close_price'], color='blue', marker='o', label='BTC Closing Price')
ax1.set_xlabel('Date')
ax1.set_ylabel('Closing Price', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Plot BTC volume on secondary y-axis
ax2 = ax1.twinx()
ax2.plot(ETH['date'], ETH['volume'], color='green', marker='x', label='BTC Volume')
ax2.set_ylabel('Volume', color='green')
ax2.tick_params(axis='y', labelcolor='green')

plt.title('BTC Closing Price and Volume Over Time')
fig.tight_layout()
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

folder_path = "data"
dfs = []
for filename in os.listdir(folder_path):
    if filename.endswith("_hist.csv"):
        coin = filename.replace("_hist.csv", "")
        df = pd.read_csv(os.path.join(folder_path, filename))
        df['coin'] = coin
        dfs.append(df)

all_crypto = pd.concat(dfs, ignore_index=True)

pivot = all_crypto.pivot_table(index='date', columns='coin', values='close_price')
corr = pivot.astype(float).corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Closing Prices for All Cryptos')
plt.tight_layout()
plt.show()
